# %%
import os
import pandas as pd

# Path to the extracted folder
folder_path = "Keyboard51-60"

# Initialize a list to store dataframes
desktop_dataframes = []

# Loop through all subfolders (user folders)
for subfolder in os.listdir(folder_path):
    subfolder_path = os.path.join(folder_path, subfolder)
    if os.path.isdir(subfolder_path):  # Check if it is a folder
        userID = subfolder  # Extract userID from the folder name
        # Look for files containing "phone" in their name
        for file in os.listdir(subfolder_path):
            if "phone" in file.lower():
                file_path = os.path.join(subfolder_path, file)
                # Read the CSV file into a DataFrame
                df = pd.read_csv(file_path)
                # Add the userID column to the DataFrame
                df['userID'] = userID
                # Append the DataFrame to the list
                desktop_dataframes.append(df)

# Combine all desktop dataframes into a single dataframe
combined_desktop_data = pd.concat(desktop_dataframes, ignore_index=True)

# Save the combined dataframe to a new CSV file
output_file_path = "combined_phone_data.csv"
combined_desktop_data.to_csv(output_file_path, index=False)

print(f"Combined desktop data saved to: {output_file_path}")
# Out:
# Combined desktop data saved to: combined_phone_data.csv

# %%
import pandas as pd  # Import the pandas library for data manipulation

# Load the dataset from the CSV file into a pandas DataFrame
data = pd.read_csv('combined_phone_data.csv')

# Convert the 'timestamp' column to datetime objects for accurate time calculations
data['timestamp'] = pd.to_datetime(data['timestamp'])

# Sort the data by 'userID' and 'timestamp' to ensure chronological order within each user
data.sort_values(by=['userID', 'timestamp'], inplace=True)

# Define parameters for creating overlapping windows
window_size = 1000             # Each sample will consist of 1000 keystroke events
overlap = 0.75                 # 75% overlap between consecutive samples
step_size = int(window_size * (1 - overlap))  # Calculate step size based on overlap (250 events)

# Initialize lists to store the samples and their corresponding labels (user IDs)
samples = []
sample_labels = []

# Iterate over each unique user in the dataset
for user_id in data['userID'].unique():
    # Extract data for the current user
    user_data = data[data['userID'] == user_id].reset_index(drop=True)
    num_events = len(user_data)  # Total number of keystroke events for this user
    
    # Calculate the number of samples that can be created from this user's data
    num_samples = (num_events - window_size) // step_size + 1
    
    # Loop to create overlapping samples for the current user
    for i in range(num_samples):
        # Calculate the starting and ending indices for the current window
        start_index = i * step_size
        end_index = start_index + window_size
        
        # Extract the sample data for the current window
        sample = user_data.iloc[start_index:end_index]
        
        # Append the sample to the list of samples
        samples.append(sample)
        
        # Append the user ID as the label for this sample
        sample_labels.append(user_id)

# %%
import numpy as np

# Initialize a list to store the processed features for each sample
processed_samples = []
keys_of_interest = ['t', 'a', 'e', 'i', 'h']

# Function to calculate hold times for a given sample
def calculate_hold_times(sample):
    hold_times = {key: [] for key in keys_of_interest}  # Initialize hold times for each key
    key_down_times = {}  # Dictionary to store the timestamp of 'DOWN' events

    # Iterate over the events in the sample
    for _, event in sample.iterrows():
        key = event['keyPressed']
        state = event['keyState']
        timestamp = event['timestamp']

        if key in keys_of_interest:
            if state == 'DOWN':
                # Record the time when the key was pressed down
                key_down_times[key] = timestamp
            elif state == 'UP' and key in key_down_times:
                # Calculate hold time when the key is released
                hold_time = (timestamp - key_down_times[key]).total_seconds()
                hold_times[key].append(hold_time)
                # Remove the key from the down times dictionary
                del key_down_times[key]
    return hold_times

# Function to remove outliers using the IQR method
def remove_outliers(hold_times):
    cleaned_hold_times = {}
    for key, times in hold_times.items():
        times_array = np.array(times)
        if len(times_array) > 0:
            # Calculate Q1 and Q3
            Q1 = np.percentile(times_array, 25)
            Q3 = np.percentile(times_array, 75)
            IQR = Q3 - Q1
            # Define bounds for non-outliers
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            # Filter out the outliers
            non_outliers = times_array[(times_array >= lower_bound) & (times_array <= upper_bound)]
            cleaned_hold_times[key] = non_outliers
        else:
            # If no times recorded for this key, assign an empty array
            cleaned_hold_times[key] = np.array([])
    return cleaned_hold_times

# Process each sample
for sample in samples:
    # Step 1: Calculate hold times for the sample
    hold_times = calculate_hold_times(sample)

    # Step 2: Remove outliers from hold times
    cleaned_hold_times = remove_outliers(hold_times)

    # Store the cleaned hold times for feature extraction in the next step
    processed_samples.append(cleaned_hold_times)

# %%
import matplotlib.pyplot as plt

# Visualize hold times before and after outlier removal
for key in keys_of_interest:
    # Collect data for all samples before and after outlier removal
    hold_times_before = []
    hold_times_after = []

    for sample in samples:
        # Calculate hold times for the sample
        hold_times = calculate_hold_times(sample)
        hold_times_before.extend(hold_times[key])

    for cleaned_hold_times in processed_samples:
        hold_times_after.extend(cleaned_hold_times[key])

    # Convert to NumPy arrays for visualization
    hold_times_before = np.array(hold_times_before)
    hold_times_after = np.array(hold_times_after)

    # Create a figure with two subplots (side by side)
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # Box plot
    axes[0].boxplot(
        [hold_times_before, hold_times_after], 
        labels=['Before IQR', 'After IQR'], 
        showmeans=True,
        patch_artist=True,
        boxprops=dict(facecolor='lightblue'),
        meanprops=dict(marker='o', markerfacecolor='red', markersize=8),
    )
    axes[0].set_title(f"Hold Times for Key '{key}' - Before and After IQR Outlier Removal")
    axes[0].set_ylabel("Hold Time (seconds)")
    axes[0].grid(axis='y', linestyle='--', alpha=0.7)

    # Histogram
    axes[1].hist(hold_times_before, bins=20, alpha=0.7, label='Before IQR', color='blue', edgecolor='black')
    axes[1].hist(hold_times_after, bins=20, alpha=0.7, label='After IQR', color='green', edgecolor='black')
    axes[1].set_title(f"Hold Time Distribution for Key '{key}' - Before and After IQR Outlier Removal")
    axes[1].set_xlabel("Hold Time (seconds)")
    axes[1].set_ylabel("Frequency")
    axes[1].legend()
    axes[1].grid(axis='y', linestyle='--', alpha=0.7)

    # Adjust layout for better spacing
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/pg/gw2rszz96l3c75cftt4ppm_00000gn/T/ipykernel_7482/3282890543.py:25: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(
# /var/folders/pg/gw2rszz96l3c75cftt4ppm_00000gn/T/ipykernel_7482/3282890543.py:25: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(
# /var/folders/pg/gw2rszz96l3c75cftt4ppm_00000gn/T/ipykernel_7482/3282890543.py:25: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(
# /var/folders/pg/gw2rszz96l3c75cftt4ppm_00000gn/T/ipykernel_7482/3282890543.py:25: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(
# /var/folders/pg/gw2rszz96l3c75cftt4ppm_00000gn/T/ipykernel_7482/3282890543.py:25: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(

# %%
import numpy as np
import pandas as pd

# Initialize lists to store feature vectors and corresponding labels
feature_vectors = []
labels = []

# Keys of interest
keys_of_interest = ['t', 'a', 'e', 'i', 'h']

# Iterate over each processed sample and its corresponding label
for idx, cleaned_hold_times in enumerate(processed_samples):
    features = []
    for key in keys_of_interest:
        times = cleaned_hold_times.get(key, np.array([]))
        if len(times) > 0:
            # Calculate mean and standard deviation
            mean_time = np.mean(times)
            std_time = np.std(times)
        else:
            # Handle missing data by assigning zero
            mean_time = 0.0
            std_time = 0.0
        # Append the features for this key
        features.extend([mean_time, std_time])
    # Append the feature vector and label to the lists
    feature_vectors.append(features)
    labels.append(sample_labels[idx])

# Convert feature vectors and labels to NumPy arrays or pandas DataFrames
feature_vectors = np.array(feature_vectors)
labels = np.array(labels)

# Optionally, create a pandas DataFrame for better visualization
feature_names = []
for key in keys_of_interest:
    feature_names.extend([f'{key}_mean', f'{key}_std'])

features_df = pd.DataFrame(feature_vectors, columns=feature_names)
labels_series = pd.Series(labels, name='userID')

# %%
features_df
# Out:
#        t_mean     t_std    a_mean     a_std    e_mean     e_std    i_mean  \
# 0    0.069544  0.012623  0.108720  0.011411  0.099556  0.014590  0.082357
# 1    0.067218  0.011296  0.109148  0.009164  0.098475  0.013154  0.083407
# 2    0.066075  0.010749  0.105500  0.009795  0.096952  0.013340  0.083857
# 3    0.067925  0.010944  0.104107  0.010903  0.097246  0.012695  0.088600
# 4    0.071132  0.010347  0.102152  0.010779  0.096102  0.013257  0.088844
# ..        ...       ...       ...       ...       ...       ...       ...
# 359  0.119409  0.025980  0.139033  0.025930  0.113026  0.017580  0.105667
# 360  0.115714  0.023879  0.130476  0.018115  0.106923  0.015259  0.115533
# 361  0.110786  0.017889  0.116526  0.019712  0.102814  0.014458  0.111000
# 362  0.112775  0.018109  0.117174  0.018948  0.102300  0.013759  0.112143
# 363  0.107765  0.019566  0.113280  0.017294  0.107810  0.016706  0.114909
#
#         i_std    h_mean     h_std
# 0    0.013880  0.083143  0.016754
# 1    0.016802  0.078667  0.015047
# 2    0.016329  0.079524  0.016014
# 3    0.015645  0.080238  0.017238
# 4    0.015545  0.080450  0.017078
# ..        ...       ...       ...
# 359  0.012136  0.120778  0.022282
# 360  0.020896  0.120095  0.021152
# 361  0.018251  0.119190  0.024655
# 362  0.022681  0.116500  0.021487
# 363  0.022617  0.122500  0.020637
#
# [364 rows x 10 columns]

# %%
labels_series

! pip3 install pydot graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydot in /Users/rashmi/Library/Python/3.9/lib/python/site-packages (3.0.3)
# Requirement already satisfied: graphviz in /Users/rashmi/Library/Python/3.9/lib/python/site-packages (0.20.3)
# Requirement already satisfied: pyparsing>=3.0.9 in /Users/rashmi/Library/Python/3.9/lib/python/site-packages (from pydot) (3.2.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import tensorflow as tf

# Step 1: Data Preparation

# Feature Scaling using StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(feature_vectors)

# Encoding labels (user IDs) to integers using LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(labels)

# Check class distribution for imbalance
unique, counts = np.unique(y_encoded, return_counts=True)
class_distribution = dict(zip(unique, counts))
print("Class Distribution:", class_distribution)

# Convert integer labels to one-hot encoded vectors
y_one_hot = to_categorical(y_encoded, num_classes=10)

# Step 2: Initialize Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Initialize lists to store test accuracies and histories for each fold
test_accuracies = []
all_histories = []

fold_no = 1
for train_index, val_index in skf.split(X_scaled, y_encoded):
    print(f"\nFold {fold_no}")
    # Split the data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_scaled[train_index], X_scaled[val_index]
    y_train_fold, y_val_fold = y_one_hot[train_index], y_one_hot[val_index]

    # Step 3: Building the Model
    model = Sequential()
    # First hidden layer with Batch Normalization and L2 Regularization
    model.add(Dense(10, input_dim=X_scaled.shape[1], kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    # Second hidden layer with Batch Normalization and L2 Regularization
    model.add(Dense(10, kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    # Output layer
    model.add(Dense(10, activation='softmax'))

    # Print the model summary
    print(f"\nModel Summary for Fold {fold_no}:")
    model.summary()

    # Step 4: Compiling the Model
    optimizer = Adam(learning_rate=0.001)
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Step 5: Define EarlyStopping Callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True,
        verbose=1
    )

    # Step 6: Training the Model with Early Stopping
    history = model.fit(
        X_train_fold,
        y_train_fold,
        epochs=200,
        batch_size=32,
        validation_data=(X_val_fold, y_val_fold),
        callbacks=[early_stopping],
        verbose=1
    )

    # Save the history
    all_histories.append(history)

    # Step 7: Evaluating the Model
    loss, accuracy = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    print(f"Validation Accuracy for Fold {fold_no}: {accuracy * 100:.2f}%")

    # Append the accuracy to the list
    test_accuracies.append(accuracy)

    # Plot training & validation accuracy and loss values
    epochs_range = range(1, len(history.history['accuracy']) + 1)
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, history.history['loss'], label='Training Loss')
    plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
    plt.title(f'Fold {fold_no} - Training vs Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
    plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Fold {fold_no} - Training vs Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

    fold_no += 1

# Step 8: Reporting Results
# Calculate the average accuracy across all folds
average_accuracy = np.mean(test_accuracies)
print(f'\nAverage Validation Accuracy over {skf.get_n_splits()} folds: {average_accuracy * 100:.2f}%')
# Out:
# Class Distribution: {np.int64(0): np.int64(38), np.int64(1): np.int64(36), np.int64(2): np.int64(28), np.int64(3): np.int64(34), np.int64(4): np.int64(37), np.int64(5): np.int64(34), np.int64(6): np.int64(33), np.int64(7): np.int64(55), np.int64(8): np.int64(32), np.int64(9): np.int64(37)}
#
# Fold 1
#
# Model Summary for Fold 1:
# /Users/rashmi/Library/Python/3.9/lib/python/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_30"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_90 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_60          │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_60 (Activation)      │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_91 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_61          │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_61 (Activation)      │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_92 (Dense)                │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 370 (1.45 KB)
#  Non-trainable params: 40 (160.00 B)
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.1379 - loss: 2.4362 - val_accuracy: 0.1148 - val_loss: 2.3096
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1343 - loss: 2.3786 - val_accuracy: 0.1475 - val_loss: 2.2786
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1308 - loss: 2.3271 - val_accuracy: 0.1639 - val_loss: 2.2491
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1396 - loss: 2.2297 - val_accuracy: 0.1803 - val_loss: 2.2197
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1701 - loss: 2.2629 - val_accuracy: 0.1803 - val_loss: 2.1900
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2000 - loss: 2.1808 - val_accuracy: 0.1967 - val_loss: 2.1614
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2140 - loss: 2.1566 - val_accuracy: 0.2131 - val_loss: 2.1337
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2332 - loss: 2.1023 - val_accuracy: 0.2377 - val_loss: 2.1066
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2200 - loss: 2.1116 - val_accuracy: 0.2541 - val_loss: 2.0814
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2570 - loss: 2.0410 - val_accuracy: 0.2787 - val_loss: 2.0563
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2548 - loss: 2.0283 - val_accuracy: 0.2623 - val_loss: 2.0323
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2602 - loss: 2.0058 - val_accuracy: 0.2705 - val_loss: 2.0101
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2320 - loss: 2.0042 - val_accuracy: 0.2787 - val_loss: 1.9882
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2888 - loss: 1.9691 - val_accuracy: 0.2787 - val_loss: 1.9671
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3388 - loss: 1.8849 - val_accuracy: 0.2787 - val_loss: 1.9453
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2748 - loss: 1.9234 - val_accuracy: 0.2951 - val_loss: 1.9252
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2957 - loss: 1.8958 - val_accuracy: 0.3115 - val_loss: 1.9052
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2839 - loss: 1.8841 - val_accuracy: 0.3525 - val_loss: 1.8843
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3961 - loss: 1.8275 - val_accuracy: 0.3934 - val_loss: 1.8646
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3353 - loss: 1.8601 - val_accuracy: 0.4016 - val_loss: 1.8440
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4728 - loss: 1.7663 - val_accuracy: 0.4016 - val_loss: 1.8244
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4737 - loss: 1.7805 - val_accuracy: 0.4098 - val_loss: 1.8045
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4964 - loss: 1.7693 - val_accuracy: 0.4180 - val_loss: 1.7846
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4753 - loss: 1.7843 - val_accuracy: 0.4344 - val_loss: 1.7638
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4849 - loss: 1.7068 - val_accuracy: 0.4344 - val_loss: 1.7431
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5128 - loss: 1.6732 - val_accuracy: 0.4508 - val_loss: 1.7219
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5264 - loss: 1.6830 - val_accuracy: 0.4590 - val_loss: 1.7009
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5307 - loss: 1.6899 - val_accuracy: 0.4590 - val_loss: 1.6799
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5200 - loss: 1.6157 - val_accuracy: 0.4754 - val_loss: 1.6582
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5242 - loss: 1.6209 - val_accuracy: 0.4836 - val_loss: 1.6368
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5639 - loss: 1.5537 - val_accuracy: 0.4836 - val_loss: 1.6171
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5932 - loss: 1.5504 - val_accuracy: 0.5000 - val_loss: 1.5959
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6300 - loss: 1.4846 - val_accuracy: 0.5082 - val_loss: 1.5744
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5630 - loss: 1.5062 - val_accuracy: 0.5164 - val_loss: 1.5514
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5746 - loss: 1.4812 - val_accuracy: 0.5246 - val_loss: 1.5280
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5743 - loss: 1.4717 - val_accuracy: 0.5246 - val_loss: 1.5064
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5376 - loss: 1.4886 - val_accuracy: 0.5328 - val_loss: 1.4820
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6007 - loss: 1.3790 - val_accuracy: 0.5492 - val_loss: 1.4574
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5815 - loss: 1.4217 - val_accuracy: 0.5574 - val_loss: 1.4361
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6059 - loss: 1.3587 - val_accuracy: 0.6066 - val_loss: 1.4121
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6091 - loss: 1.3140 - val_accuracy: 0.6066 - val_loss: 1.3883
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6280 - loss: 1.2928 - val_accuracy: 0.6148 - val_loss: 1.3644
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6147 - loss: 1.3263 - val_accuracy: 0.6230 - val_loss: 1.3421
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6270 - loss: 1.2748 - val_accuracy: 0.6230 - val_loss: 1.3178
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6534 - loss: 1.2320 - val_accuracy: 0.6230 - val_loss: 1.2938
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6453 - loss: 1.1958 - val_accuracy: 0.6393 - val_loss: 1.2699
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6423 - loss: 1.2139 - val_accuracy: 0.6393 - val_loss: 1.2479
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6811 - loss: 1.1736 - val_accuracy: 0.6393 - val_loss: 1.2280
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7216 - loss: 1.1417 - val_accuracy: 0.6475 - val_loss: 1.2100
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7298 - loss: 1.0992 - val_accuracy: 0.6639 - val_loss: 1.1891
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7004 - loss: 1.1421 - val_accuracy: 0.6721 - val_loss: 1.1674
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7339 - loss: 1.0728 - val_accuracy: 0.6803 - val_loss: 1.1469
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7084 - loss: 1.0576 - val_accuracy: 0.6885 - val_loss: 1.1255
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7061 - loss: 1.0832 - val_accuracy: 0.6803 - val_loss: 1.1064
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7329 - loss: 1.0282 - val_accuracy: 0.6885 - val_loss: 1.0861
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7252 - loss: 1.0154 - val_accuracy: 0.6967 - val_loss: 1.0685
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7384 - loss: 1.0085 - val_accuracy: 0.6967 - val_loss: 1.0524
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6985 - loss: 1.0691 - val_accuracy: 0.7213 - val_loss: 1.0362
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7572 - loss: 0.9970 - val_accuracy: 0.7213 - val_loss: 1.0217
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7218 - loss: 0.9834 - val_accuracy: 0.7377 - val_loss: 1.0070
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7244 - loss: 0.9598 - val_accuracy: 0.7541 - val_loss: 0.9954
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7683 - loss: 0.9244 - val_accuracy: 0.7541 - val_loss: 0.9844
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7428 - loss: 0.9016 - val_accuracy: 0.7541 - val_loss: 0.9728
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7349 - loss: 0.9622 - val_accuracy: 0.7459 - val_loss: 0.9603
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7438 - loss: 0.9243 - val_accuracy: 0.7623 - val_loss: 0.9447
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7484 - loss: 0.9313 - val_accuracy: 0.7623 - val_loss: 0.9309
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7272 - loss: 0.9220 - val_accuracy: 0.7623 - val_loss: 0.9164
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7827 - loss: 0.8608 - val_accuracy: 0.7705 - val_loss: 0.9041
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7424 - loss: 0.9169 - val_accuracy: 0.7623 - val_loss: 0.8906
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7869 - loss: 0.8321 - val_accuracy: 0.7787 - val_loss: 0.8802
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7415 - loss: 0.8801 - val_accuracy: 0.7705 - val_loss: 0.8690
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7660 - loss: 0.8858 - val_accuracy: 0.7705 - val_loss: 0.8586
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8074 - loss: 0.8054 - val_accuracy: 0.7705 - val_loss: 0.8505
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7341 - loss: 0.8495 - val_accuracy: 0.7705 - val_loss: 0.8422
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7880 - loss: 0.8255 - val_accuracy: 0.7705 - val_loss: 0.8345
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7586 - loss: 0.8301 - val_accuracy: 0.7787 - val_loss: 0.8257
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7834 - loss: 0.8086 - val_accuracy: 0.7869 - val_loss: 0.8166
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7947 - loss: 0.7783 - val_accuracy: 0.7787 - val_loss: 0.8085
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8275 - loss: 0.7682 - val_accuracy: 0.7951 - val_loss: 0.8011
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8310 - loss: 0.7150 - val_accuracy: 0.7951 - val_loss: 0.7933
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8120 - loss: 0.7150 - val_accuracy: 0.7951 - val_loss: 0.7876
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.7092 - val_accuracy: 0.7951 - val_loss: 0.7798
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7652 - loss: 0.7943 - val_accuracy: 0.7951 - val_loss: 0.7699
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8045 - loss: 0.7109 - val_accuracy: 0.7951 - val_loss: 0.7582
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8207 - loss: 0.7303 - val_accuracy: 0.8033 - val_loss: 0.7484
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8366 - loss: 0.7049 - val_accuracy: 0.7951 - val_loss: 0.7368
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8101 - loss: 0.7096 - val_accuracy: 0.8115 - val_loss: 0.7293
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7363 - loss: 0.8338 - val_accuracy: 0.8115 - val_loss: 0.7225
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7826 - loss: 0.7254 - val_accuracy: 0.8115 - val_loss: 0.7168
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7802 - loss: 0.8038 - val_accuracy: 0.8033 - val_loss: 0.7044
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8047 - loss: 0.7231 - val_accuracy: 0.8115 - val_loss: 0.6964
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7719 - loss: 0.7997 - val_accuracy: 0.8197 - val_loss: 0.6904
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7919 - loss: 0.7039 - val_accuracy: 0.8197 - val_loss: 0.6831
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7938 - loss: 0.6516 - val_accuracy: 0.8197 - val_loss: 0.6771
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8367 - loss: 0.6472 - val_accuracy: 0.8279 - val_loss: 0.6715
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7764 - loss: 0.7086 - val_accuracy: 0.8279 - val_loss: 0.6666
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7973 - loss: 0.6598 - val_accuracy: 0.8279 - val_loss: 0.6588
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8360 - loss: 0.6484 - val_accuracy: 0.8279 - val_loss: 0.6534
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7865 - loss: 0.6616 - val_accuracy: 0.8279 - val_loss: 0.6498
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8233 - loss: 0.6270 - val_accuracy: 0.8279 - val_loss: 0.6435
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7719 - loss: 0.7155 - val_accuracy: 0.8279 - val_loss: 0.6371
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8341 - loss: 0.5820 - val_accuracy: 0.8279 - val_loss: 0.6320
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7917 - loss: 0.6544 - val_accuracy: 0.8279 - val_loss: 0.6263
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7997 - loss: 0.5984 - val_accuracy: 0.8279 - val_loss: 0.6217
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.7009 - val_accuracy: 0.8279 - val_loss: 0.6177
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7996 - loss: 0.5936 - val_accuracy: 0.8279 - val_loss: 0.6100
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8082 - loss: 0.6225 - val_accuracy: 0.8361 - val_loss: 0.6017
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8859 - loss: 0.5778 - val_accuracy: 0.8443 - val_loss: 0.5936
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8053 - loss: 0.5841 - val_accuracy: 0.8443 - val_loss: 0.5861
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.6072 - val_accuracy: 0.8361 - val_loss: 0.5809
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8198 - loss: 0.6723 - val_accuracy: 0.8443 - val_loss: 0.5753
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8435 - loss: 0.5793 - val_accuracy: 0.8443 - val_loss: 0.5694
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8515 - loss: 0.5428 - val_accuracy: 0.8443 - val_loss: 0.5629
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8088 - loss: 0.5709 - val_accuracy: 0.8525 - val_loss: 0.5573
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8509 - loss: 0.5563 - val_accuracy: 0.8525 - val_loss: 0.5543
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8349 - loss: 0.5425 - val_accuracy: 0.8525 - val_loss: 0.5503
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8519 - loss: 0.5431 - val_accuracy: 0.8525 - val_loss: 0.5451
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8386 - loss: 0.5180 - val_accuracy: 0.8525 - val_loss: 0.5410
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.5186 - val_accuracy: 0.8525 - val_loss: 0.5365
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8360 - loss: 0.5743 - val_accuracy: 0.8525 - val_loss: 0.5314
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8389 - loss: 0.5229 - val_accuracy: 0.8525 - val_loss: 0.5299
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8475 - loss: 0.5196 - val_accuracy: 0.8525 - val_loss: 0.5272
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8669 - loss: 0.5128 - val_accuracy: 0.8525 - val_loss: 0.5223
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8102 - loss: 0.5512 - val_accuracy: 0.8525 - val_loss: 0.5182
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8568 - loss: 0.4975 - val_accuracy: 0.8525 - val_loss: 0.5141
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8063 - loss: 0.5528 - val_accuracy: 0.8525 - val_loss: 0.5114
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8141 - loss: 0.5225 - val_accuracy: 0.8607 - val_loss: 0.5095
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.5361 - val_accuracy: 0.8525 - val_loss: 0.5071
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8258 - loss: 0.5221 - val_accuracy: 0.8525 - val_loss: 0.5021
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8733 - loss: 0.4467 - val_accuracy: 0.8525 - val_loss: 0.4981
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8310 - loss: 0.5123 - val_accuracy: 0.8443 - val_loss: 0.4967
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8308 - loss: 0.5638 - val_accuracy: 0.8607 - val_loss: 0.4952
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8812 - loss: 0.4742 - val_accuracy: 0.8607 - val_loss: 0.4900
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8642 - loss: 0.4760 - val_accuracy: 0.8607 - val_loss: 0.4866
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8765 - loss: 0.4540 - val_accuracy: 0.8607 - val_loss: 0.4811
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8788 - loss: 0.4610 - val_accuracy: 0.8607 - val_loss: 0.4756
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8821 - loss: 0.4470 - val_accuracy: 0.8525 - val_loss: 0.4710
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8622 - loss: 0.4712 - val_accuracy: 0.8443 - val_loss: 0.4659
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9017 - loss: 0.4235 - val_accuracy: 0.8525 - val_loss: 0.4642
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8345 - loss: 0.5709 - val_accuracy: 0.8607 - val_loss: 0.4625
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8652 - loss: 0.4618 - val_accuracy: 0.8607 - val_loss: 0.4618
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8856 - loss: 0.4614 - val_accuracy: 0.8689 - val_loss: 0.4553
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8719 - loss: 0.4529 - val_accuracy: 0.8689 - val_loss: 0.4504
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8296 - loss: 0.4946 - val_accuracy: 0.8770 - val_loss: 0.4474
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8755 - loss: 0.4061 - val_accuracy: 0.8689 - val_loss: 0.4453
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8654 - loss: 0.4355 - val_accuracy: 0.8689 - val_loss: 0.4434
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8858 - loss: 0.4054 - val_accuracy: 0.8689 - val_loss: 0.4419
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9046 - loss: 0.3825 - val_accuracy: 0.8689 - val_loss: 0.4391
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8759 - loss: 0.4368 - val_accuracy: 0.8689 - val_loss: 0.4375
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8879 - loss: 0.4014 - val_accuracy: 0.8770 - val_loss: 0.4351
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9003 - loss: 0.4062 - val_accuracy: 0.8770 - val_loss: 0.4318
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8976 - loss: 0.3904 - val_accuracy: 0.8770 - val_loss: 0.4278
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8457 - loss: 0.4764 - val_accuracy: 0.8770 - val_loss: 0.4270
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8547 - loss: 0.4452 - val_accuracy: 0.8770 - val_loss: 0.4263
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8801 - loss: 0.4302 - val_accuracy: 0.8689 - val_loss: 0.4263
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8872 - loss: 0.4032 - val_accuracy: 0.8689 - val_loss: 0.4251
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8596 - loss: 0.4460 - val_accuracy: 0.8689 - val_loss: 0.4267
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8721 - loss: 0.3682 - val_accuracy: 0.8770 - val_loss: 0.4240
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8951 - loss: 0.3776 - val_accuracy: 0.8770 - val_loss: 0.4171
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8613 - loss: 0.4224 - val_accuracy: 0.8770 - val_loss: 0.4077
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8860 - loss: 0.3826 - val_accuracy: 0.8934 - val_loss: 0.4044
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8562 - loss: 0.4723 - val_accuracy: 0.8934 - val_loss: 0.4031
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8823 - loss: 0.4148 - val_accuracy: 0.8852 - val_loss: 0.4005
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8930 - loss: 0.3823 - val_accuracy: 0.8852 - val_loss: 0.3985
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8469 - loss: 0.5011 - val_accuracy: 0.8852 - val_loss: 0.4007
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8753 - loss: 0.3921 - val_accuracy: 0.8852 - val_loss: 0.4012
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8932 - loss: 0.3730 - val_accuracy: 0.8852 - val_loss: 0.3981
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8919 - loss: 0.3575 - val_accuracy: 0.8770 - val_loss: 0.3917
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9207 - loss: 0.3315 - val_accuracy: 0.8934 - val_loss: 0.3904
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9105 - loss: 0.3660 - val_accuracy: 0.8852 - val_loss: 0.3876
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8878 - loss: 0.3757 - val_accuracy: 0.8852 - val_loss: 0.3847
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8446 - loss: 0.4922 - val_accuracy: 0.9016 - val_loss: 0.3860
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9039 - loss: 0.3840 - val_accuracy: 0.9098 - val_loss: 0.3869
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8747 - loss: 0.4185 - val_accuracy: 0.8934 - val_loss: 0.3830
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.3463 - val_accuracy: 0.8934 - val_loss: 0.3826
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9337 - loss: 0.3234 - val_accuracy: 0.8934 - val_loss: 0.3789
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8978 - loss: 0.3166 - val_accuracy: 0.8934 - val_loss: 0.3753
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8730 - loss: 0.3748 - val_accuracy: 0.8934 - val_loss: 0.3730
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9040 - loss: 0.3235 - val_accuracy: 0.8934 - val_loss: 0.3742
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8995 - loss: 0.3472 - val_accuracy: 0.8934 - val_loss: 0.3714
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8986 - loss: 0.3630 - val_accuracy: 0.9016 - val_loss: 0.3707
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9108 - loss: 0.2997 - val_accuracy: 0.9098 - val_loss: 0.3678
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8897 - loss: 0.3770 - val_accuracy: 0.9016 - val_loss: 0.3630
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9063 - loss: 0.3289 - val_accuracy: 0.9016 - val_loss: 0.3602
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8526 - loss: 0.3961 - val_accuracy: 0.9016 - val_loss: 0.3555
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8778 - loss: 0.3986 - val_accuracy: 0.9098 - val_loss: 0.3517
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9132 - loss: 0.3278 - val_accuracy: 0.8934 - val_loss: 0.3520
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8787 - loss: 0.4091 - val_accuracy: 0.9016 - val_loss: 0.3497
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8736 - loss: 0.3841 - val_accuracy: 0.9016 - val_loss: 0.3494
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9220 - loss: 0.2867 - val_accuracy: 0.9098 - val_loss: 0.3469
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9004 - loss: 0.3487 - val_accuracy: 0.9016 - val_loss: 0.3453
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8931 - loss: 0.3919 - val_accuracy: 0.9016 - val_loss: 0.3458
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8526 - loss: 0.4318 - val_accuracy: 0.8934 - val_loss: 0.3490
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9245 - loss: 0.2895 - val_accuracy: 0.9098 - val_loss: 0.3475
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9225 - loss: 0.2887 - val_accuracy: 0.9098 - val_loss: 0.3447
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8661 - loss: 0.3629 - val_accuracy: 0.9180 - val_loss: 0.3427
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8399 - loss: 0.4105 - val_accuracy: 0.9180 - val_loss: 0.3389
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9239 - loss: 0.3173 - val_accuracy: 0.9180 - val_loss: 0.3347
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9158 - loss: 0.3133 - val_accuracy: 0.9016 - val_loss: 0.3299
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.2719 - val_accuracy: 0.9016 - val_loss: 0.3275
# Restoring model weights from the end of the best epoch: 200.
# Validation Accuracy for Fold 1: 90.16%
# Fold 2
#
# Model Summary for Fold 2:
# Model: "sequential_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_93 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_62          │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_62 (Activation)      │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_63          │ (None, 10)             │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_63 (Activation)      │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 10)             │           110 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 370 (1.45 KB)
#  Non-trainable params: 40 (160.00 B)
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0767 - loss: 2.4284 - val_accuracy: 0.0661 - val_loss: 2.3247
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0988 - loss: 2.3413 - val_accuracy: 0.0661 - val_loss: 2.2983
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1068 - loss: 2.2964 - val_accuracy: 0.0579 - val_loss: 2.2749
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1069 - loss: 2.2845 - val_accuracy: 0.0826 - val_loss: 2.2542
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1204 - loss: 2.2212 - val_accuracy: 0.0744 - val_loss: 2.2353
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1172 - loss: 2.2026 - val_accuracy: 0.0744 - val_loss: 2.2155
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1611 - loss: 2.1338 - val_accuracy: 0.1157 - val_loss: 2.1941
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2315 - loss: 2.1160 - val_accuracy: 0.1157 - val_loss: 2.1725
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2668 - loss: 2.0415 - val_accuracy: 0.1488 - val_loss: 2.1511
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3323 - loss: 2.0021 - val_accuracy: 0.1901 - val_loss: 2.1287
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3120 - loss: 2.0016 - val_accuracy: 0.2479 - val_loss: 2.1068
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3603 - loss: 1.9700 - val_accuracy: 0.2727 - val_loss: 2.0848
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3775 - loss: 1.9577 - val_accuracy: 0.3140 - val_loss: 2.0625
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4316 - loss: 1.9321 - val_accuracy: 0.3306 - val_loss: 2.0389
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3889 - loss: 1.9309 - val_accuracy: 0.3223 - val_loss: 2.0145
# Epoch 16/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4666 - loss: 1.8505 - val_accuracy: 0.3471 - val_loss: 1.9913
# Epoch 17/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4812 - loss: 1.8884 - val_accuracy: 0.3554 - val_loss: 1.9701
# Epoch 18/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4089 - loss: 1.8659 - val_accuracy: 0.3636 - val_loss: 1.9478
# Epoch 19/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4801 - loss: 1.7971 - val_accuracy: 0.3884 - val_loss: 1.9250
# Epoch 20/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4453 - loss: 1.8205 - val_accuracy: 0.4050 - val_loss: 1.9036
# Epoch 21/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4769 - loss: 1.8088 - val_accuracy: 0.4215 - val_loss: 1.8813
# Epoch 22/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5004 - loss: 1.7615 - val_accuracy: 0.4132 - val_loss: 1.8584
# Epoch 23/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4824 - loss: 1.7625 - val_accuracy: 0.4298 - val_loss: 1.8365
# Epoch 24/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5148 - loss: 1.7195 - val_accuracy: 0.4793 - val_loss: 1.8139
# Epoch 25/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5756 - loss: 1.6922 - val_accuracy: 0.5041 - val_loss: 1.7912
# Epoch 26/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5490 - loss: 1.6913 - val_accuracy: 0.5124 - val_loss: 1.7690
# Epoch 27/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5491 - loss: 1.6792 - val_accuracy: 0.4959 - val_loss: 1.7478
# Epoch 28/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5755 - loss: 1.6072 - val_accuracy: 0.5207 - val_loss: 1.7265
# Epoch 29/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5017 - loss: 1.6438 - val_accuracy: 0.5124 - val_loss: 1.7079
# Epoch 30/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5678 - loss: 1.6077 - val_accuracy: 0.5124 - val_loss: 1.6876
# Epoch 31/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5176 - loss: 1.6274 - val_accuracy: 0.5372 - val_loss: 1.6677
# Epoch 32/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5824 - loss: 1.5464 - val_accuracy: 0.5455 - val_loss: 1.6454
# Epoch 33/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5844 - loss: 1.5218 - val_accuracy: 0.5537 - val_loss: 1.6232
# Epoch 34/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5946 - loss: 1.5244 - val_accuracy: 0.5868 - val_loss: 1.6018
# Epoch 35/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6281 - loss: 1.4707 - val_accuracy: 0.5950 - val_loss: 1.5812
# Epoch 36/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5898 - loss: 1.4878 - val_accuracy: 0.6116 - val_loss: 1.5615
# Epoch 37/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6072 - loss: 1.4415 - val_accuracy: 0.6116 - val_loss: 1.5425
# Epoch 38/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5578 - loss: 1.4876 - val_accuracy: 0.6116 - val_loss: 1.5230
# Epoch 39/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6392 - loss: 1.3892 - val_accuracy: 0.6116 - val_loss: 1.5039
# Epoch 40/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5911 - loss: 1.4255 - val_accuracy: 0.6033 - val_loss: 1.4841
# Epoch 41/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6223 - loss: 1.3720 - val_accuracy: 0.6116 - val_loss: 1.4649
# Epoch 42/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6535 - loss: 1.3452 - val_accuracy: 0.6281 - val_loss: 1.4464
# Epoch 43/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6462 - loss: 1.2996 - val_accuracy: 0.6446 - val_loss: 1.4266
# Epoch 44/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6447 - loss: 1.3318 - val_accuracy: 0.6446 - val_loss: 1.4067
# Epoch 45/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6464 - loss: 1.3328 - val_accuracy: 0.6529 - val_loss: 1.3884
# Epoch 46/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6345 - loss: 1.3227 - val_accuracy: 0.6446 - val_loss: 1.3726
# Epoch 47/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6607 - loss: 1.2494 - val_accuracy: 0.6446 - val_loss: 1.3537
# Epoch 48/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6362 - loss: 1.2307 - val_accuracy: 0.6529 - val_loss: 1.3357
# Epoch 49/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6602 - loss: 1.2489 - val_accuracy: 0.6612 - val_loss: 1.3177
# Epoch 50/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7072 - loss: 1.1690 - val_accuracy: 0.6612 - val_loss: 1.3006
# Epoch 51/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6547 - loss: 1.2394 - val_accuracy: 0.6777 - val_loss: 1.2826
# Epoch 52/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6701 - loss: 1.1906 - val_accuracy: 0.6942 - val_loss: 1.2617
# Epoch 53/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7028 - loss: 1.1651 - val_accuracy: 0.6860 - val_loss: 1.2438
# Epoch 54/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7652 - loss: 1.0819 - val_accuracy: 0.7025 - val_loss: 1.2255
# Epoch 55/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6995 - loss: 1.1265 - val_accuracy: 0.7025 - val_loss: 1.2064
# Epoch 56/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7483 - loss: 1.0639 - val_accuracy: 0.7107 - val_loss: 1.1880
# Epoch 57/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7591 - loss: 1.0144 - val_accuracy: 0.7107 - val_loss: 1.1714
# Epoch 58/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7066 - loss: 1.0779 - val_accuracy: 0.7107 - val_loss: 1.1582
# Epoch 59/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7400 - loss: 1.0502 - val_accuracy: 0.7190 - val_loss: 1.1436
# Epoch 60/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7173 - loss: 1.0479 - val_accuracy: 0.7190 - val_loss: 1.1274
# Epoch 61/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7429 - loss: 1.0218 - val_accuracy: 0.7190 - val_loss: 1.1097
# Epoch 62/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7094 - loss: 1.0229 - val_accuracy: 0.7273 - val_loss: 1.0939
# Epoch 63/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7714 - loss: 0.9614 - val_accuracy: 0.7355 - val_loss: 1.0768
# Epoch 64/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7577 - loss: 0.9567 - val_accuracy: 0.7355 - val_loss: 1.0625
# Epoch 65/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7824 - loss: 0.8863 - val_accuracy: 0.7355 - val_loss: 1.0468
# Epoch 66/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7093 - loss: 0.9658 - val_accuracy: 0.7438 - val_loss: 1.0297
# Epoch 67/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7668 - loss: 0.8933 - val_accuracy: 0.7603 - val_loss: 1.0140
# Epoch 68/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7717 - loss: 0.8786 - val_accuracy: 0.7603 - val_loss: 0.9978
# Epoch 69/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7585 - loss: 0.9023 - val_accuracy: 0.7686 - val_loss: 0.9846
# Epoch 70/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8166 - loss: 0.8309 - val_accuracy: 0.7769 - val_loss: 0.9751
# Epoch 71/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8119 - loss: 0.8619 - val_accuracy: 0.7769 - val_loss: 0.9615
# Epoch 72/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8230 - loss: 0.8300 - val_accuracy: 0.7934 - val_loss: 0.9408
# Epoch 73/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8068 - loss: 0.7957 - val_accuracy: 0.7934 - val_loss: 0.9276
# Epoch 74/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8474 - loss: 0.7953 - val_accuracy: 0.8017 - val_loss: 0.9144
# Epoch 75/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7942 - loss: 0.8142 - val_accuracy: 0.8017 - val_loss: 0.8966
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8033 - loss: 0.8224 - val_accuracy: 0.7934 - val_loss: 0.8790
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7975 - loss: 0.7673 - val_accuracy: 0.8017 - val_loss: 0.8605
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8811 - loss: 0.7109 - val_accuracy: 0.8017 - val_loss: 0.8502
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8294 - loss: 0.7221 - val_accuracy: 0.8017 - val_loss: 0.8421
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8409 - loss: 0.7148 - val_accuracy: 0.8017 - val_loss: 0.8350
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7818 - loss: 0.7660 - val_accuracy: 0.8099 - val_loss: 0.8237
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8499 - loss: 0.6736 - val_accuracy: 0.8099 - val_loss: 0.8146
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8494 - loss: 0.6711 - val_accuracy: 0.8017 - val_loss: 0.8011
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8694 - loss: 0.6337 - val_accuracy: 0.8017 - val_loss: 0.7872
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8583 - loss: 0.6169 - val_accuracy: 0.8017 - val_loss: 0.7739
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7672 - loss: 0.7654 - val_accuracy: 0.8017 - val_loss: 0.7625
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8485 - loss: 0.6713 - val_accuracy: 0.8182 - val_loss: 0.7488
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8877 - loss: 0.5765 - val_accuracy: 0.8347 - val_loss: 0.7394
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8596 - loss: 0.6087 - val_accuracy: 0.8347 - val_loss: 0.7283
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8580 - loss: 0.5952 - val_accuracy: 0.8347 - val_loss: 0.7194
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8571 - loss: 0.5917 - val_accuracy: 0.8347 - val_loss: 0.7100
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8538 - loss: 0.5965 - val_accuracy: 0.8347 - val_loss: 0.7007
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8872 - loss: 0.5563 - val_accuracy: 0.8347 - val_loss: 0.6926
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8511 - loss: 0.6313 - val_accuracy: 0.8430 - val_loss: 0.6846
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8766 - loss: 0.5652 - val_accuracy: 0.8430 - val_loss: 0.6768
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8807 - loss: 0.5411 - val_accuracy: 0.8264 - val_loss: 0.6670
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8926 - loss: 0.5213 - val_accuracy: 0.8347 - val_loss: 0.6605
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.5783 - val_accuracy: 0.8347 - val_loss: 0.6568
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8760 - loss: 0.5740 - val_accuracy: 0.8430 - val_loss: 0.6536
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8813 - loss: 0.5177 - val_accuracy: 0.8512 - val_loss: 0.6459
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8688 - loss: 0.5516 - val_accuracy: 0.8512 - val_loss: 0.6359
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8977 - loss: 0.4899 - val_accuracy: 0.8595 - val_loss: 0.6310
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8834 - loss: 0.5145 - val_accuracy: 0.8512 - val_loss: 0.6171
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8643 - loss: 0.5419 - val_accuracy: 0.8678 - val_loss: 0.6030
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8785 - loss: 0.4931 - val_accuracy: 0.8512 - val_loss: 0.5999
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9149 - loss: 0.4756 - val_accuracy: 0.8512 - val_loss: 0.5949
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.4387 - val_accuracy: 0.8512 - val_loss: 0.5928
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9146 - loss: 0.4818 - val_accuracy: 0.8595 - val_loss: 0.5947
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8931 - loss: 0.4626 - val_accuracy: 0.8595 - val_loss: 0.5897
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9252 - loss: 0.4176 - val_accuracy: 0.8595 - val_loss: 0.5804
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9340 - loss: 0.4212 - val_accuracy: 0.8678 - val_loss: 0.5698
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9205 - loss: 0.4328 - val_accuracy: 0.8843 - val_loss: 0.5586
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.4185 - val_accuracy: 0.8760 - val_loss: 0.5524
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.3933 - val_accuracy: 0.8843 - val_loss: 0.5516
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8974 - loss: 0.4393 - val_accuracy: 0.8760 - val_loss: 0.5488
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9029 - loss: 0.4446 - val_accuracy: 0.8678 - val_loss: 0.5408
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9228 - loss: 0.3802 - val_accuracy: 0.8760 - val_loss: 0.5314
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9256 - loss: 0.3840 - val_accuracy: 0.8926 - val_loss: 0.5238
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8950 - loss: 0.4051 - val_accuracy: 0.8843 - val_loss: 0.5166
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.4328 - val_accuracy: 0.8843 - val_loss: 0.5090
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9155 - loss: 0.4220 - val_accuracy: 0.9008 - val_loss: 0.4984
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9123 - loss: 0.4222 - val_accuracy: 0.9008 - val_loss: 0.4977
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9504 - loss: 0.3249 - val_accuracy: 0.8843 - val_loss: 0.5018
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9261 - loss: 0.3586 - val_accuracy: 0.8843 - val_loss: 0.4956
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8873 - loss: 0.4288 - val_accuracy: 0.8843 - val_loss: 0.4835
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9403 - loss: 0.3443 - val_accuracy: 0.9091 - val_loss: 0.4767
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9451 - loss: 0.3355 - val_accuracy: 0.9008 - val_loss: 0.4721
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.3385 - val_accuracy: 0.9008 - val_loss: 0.4674
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9542 - loss: 0.3071 - val_accuracy: 0.8843 - val_loss: 0.4664
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9277 - loss: 0.3520 - val_accuracy: 0.8843 - val_loss: 0.4662
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9264 - loss: 0.3671 - val_accuracy: 0.8843 - val_loss: 0.4609
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9354 - loss: 0.3788 - val_accuracy: 0.8843 - val_loss: 0.4583
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9083 - loss: 0.4080 - val_accuracy: 0.8926 - val_loss: 0.4536
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9227 - loss: 0.3423 - val_accuracy: 0.8926 - val_loss: 0.4507
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9234 - loss: 0.3546 - val_accuracy: 0.8926 - val_loss: 0.4398
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9259 - loss: 0.3607 - val_accuracy: 0.8926 - val_loss: 0.4345
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9526 - loss: 0.2993 - val_accuracy: 0.9008 - val_loss: 0.4360
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9262 - loss: 0.3447 - val_accuracy: 0.9091 - val_loss: 0.4299
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9767 - loss: 0.2583 - val_accuracy: 0.9091 - val_loss: 0.4262
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8951 - loss: 0.4088 - val_accuracy: 0.9174 - val_loss: 0.4214
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9319 - loss: 0.3639 - val_accuracy: 0.9091 - val_loss: 0.4163
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9400 - loss: 0.3566 - val_accuracy: 0.9008 - val_loss: 0.4143
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9469 - loss: 0.2993 - val_accuracy: 0.9008 - val_loss: 0.4134
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9627 - loss: 0.2885 - val_accuracy: 0.9008 - val_loss: 0.4123
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9522 - loss: 0.2882 - val_accuracy: 0.9008 - val_loss: 0.4141
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.3426 - val_accuracy: 0.9008 - val_loss: 0.4109
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9136 - loss: 0.3520 - val_accuracy: 0.9174 - val_loss: 0.4089
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9382 - loss: 0.2835 - val_accuracy: 0.9091 - val_loss: 0.4077
# Epoch 149/200
# ...
# Epoch 76/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8314 - loss: 0.7794 - val_accuracy: 0.7355 - val_loss: 0.8572
# Epoch 77/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7797 - loss: 0.8248 - val_accuracy: 0.7273 - val_loss: 0.8460
# Epoch 78/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7273 - loss: 0.8906 - val_accuracy: 0.7521 - val_loss: 0.8364
# Epoch 79/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8122 - loss: 0.7470 - val_accuracy: 0.7438 - val_loss: 0.8261
# Epoch 80/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7875 - loss: 0.7718 - val_accuracy: 0.7686 - val_loss: 0.8184
# Epoch 81/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8081 - loss: 0.7737 - val_accuracy: 0.7521 - val_loss: 0.8129
# Epoch 82/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7737 - loss: 0.7767 - val_accuracy: 0.7603 - val_loss: 0.8035
# Epoch 83/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7555 - loss: 0.8534 - val_accuracy: 0.7769 - val_loss: 0.7948
# Epoch 84/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7989 - loss: 0.7841 - val_accuracy: 0.7769 - val_loss: 0.7868
# Epoch 85/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8278 - loss: 0.6697 - val_accuracy: 0.7769 - val_loss: 0.7794
# Epoch 86/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8257 - loss: 0.7163 - val_accuracy: 0.7769 - val_loss: 0.7682
# Epoch 87/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8134 - loss: 0.7447 - val_accuracy: 0.7851 - val_loss: 0.7583
# Epoch 88/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8231 - loss: 0.6925 - val_accuracy: 0.7769 - val_loss: 0.7498
# Epoch 89/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8388 - loss: 0.7030 - val_accuracy: 0.7769 - val_loss: 0.7453
# Epoch 90/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8495 - loss: 0.6831 - val_accuracy: 0.7851 - val_loss: 0.7368
# Epoch 91/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8603 - loss: 0.6713 - val_accuracy: 0.8017 - val_loss: 0.7285
# Epoch 92/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7725 - loss: 0.7140 - val_accuracy: 0.7769 - val_loss: 0.7224
# Epoch 93/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8878 - loss: 0.5929 - val_accuracy: 0.7686 - val_loss: 0.7139
# Epoch 94/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8139 - loss: 0.7346 - val_accuracy: 0.7603 - val_loss: 0.7059
# Epoch 95/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8602 - loss: 0.6174 - val_accuracy: 0.7686 - val_loss: 0.6998
# Epoch 96/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8574 - loss: 0.6191 - val_accuracy: 0.7851 - val_loss: 0.6907
# Epoch 97/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.5797 - val_accuracy: 0.7934 - val_loss: 0.6809
# Epoch 98/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8285 - loss: 0.5883 - val_accuracy: 0.8017 - val_loss: 0.6739
# Epoch 99/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8954 - loss: 0.5760 - val_accuracy: 0.8099 - val_loss: 0.6696
# Epoch 100/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8638 - loss: 0.5593 - val_accuracy: 0.8099 - val_loss: 0.6651
# Epoch 101/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8376 - loss: 0.6422 - val_accuracy: 0.8017 - val_loss: 0.6570
# Epoch 102/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8696 - loss: 0.5946 - val_accuracy: 0.7934 - val_loss: 0.6543
# Epoch 103/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8147 - loss: 0.6409 - val_accuracy: 0.7934 - val_loss: 0.6489
# Epoch 104/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7745 - loss: 0.7250 - val_accuracy: 0.8099 - val_loss: 0.6426
# Epoch 105/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8968 - loss: 0.5367 - val_accuracy: 0.8099 - val_loss: 0.6356
# Epoch 106/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8436 - loss: 0.6131 - val_accuracy: 0.8099 - val_loss: 0.6341
# Epoch 107/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8860 - loss: 0.5366 - val_accuracy: 0.8099 - val_loss: 0.6260
# Epoch 108/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8466 - loss: 0.5646 - val_accuracy: 0.8182 - val_loss: 0.6192
# Epoch 109/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8617 - loss: 0.5244 - val_accuracy: 0.8347 - val_loss: 0.6128
# Epoch 110/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8835 - loss: 0.5359 - val_accuracy: 0.8347 - val_loss: 0.6078
# Epoch 111/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8766 - loss: 0.5302 - val_accuracy: 0.8264 - val_loss: 0.6010
# Epoch 112/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7933 - loss: 0.6864 - val_accuracy: 0.8264 - val_loss: 0.5954
# Epoch 113/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8766 - loss: 0.5439 - val_accuracy: 0.8182 - val_loss: 0.5907
# Epoch 114/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8292 - loss: 0.6067 - val_accuracy: 0.8264 - val_loss: 0.5893
# Epoch 115/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8817 - loss: 0.4993 - val_accuracy: 0.8347 - val_loss: 0.5873
# Epoch 116/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8923 - loss: 0.4733 - val_accuracy: 0.8347 - val_loss: 0.5846
# Epoch 117/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9014 - loss: 0.4816 - val_accuracy: 0.8430 - val_loss: 0.5773
# Epoch 118/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8906 - loss: 0.5240 - val_accuracy: 0.8430 - val_loss: 0.5711
# Epoch 119/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8881 - loss: 0.4841 - val_accuracy: 0.8430 - val_loss: 0.5673
# Epoch 120/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8703 - loss: 0.4979 - val_accuracy: 0.8430 - val_loss: 0.5657
# Epoch 121/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8801 - loss: 0.4975 - val_accuracy: 0.8430 - val_loss: 0.5643
# Epoch 122/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8224 - loss: 0.6263 - val_accuracy: 0.8347 - val_loss: 0.5604
# Epoch 123/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8696 - loss: 0.5002 - val_accuracy: 0.8347 - val_loss: 0.5530
# Epoch 124/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9046 - loss: 0.4602 - val_accuracy: 0.8430 - val_loss: 0.5470
# Epoch 125/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8588 - loss: 0.5102 - val_accuracy: 0.8347 - val_loss: 0.5426
# Epoch 126/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8999 - loss: 0.4298 - val_accuracy: 0.8347 - val_loss: 0.5401
# Epoch 127/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8851 - loss: 0.4274 - val_accuracy: 0.8347 - val_loss: 0.5416
# Epoch 128/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8906 - loss: 0.4644 - val_accuracy: 0.8512 - val_loss: 0.5376
# Epoch 129/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8773 - loss: 0.4464 - val_accuracy: 0.8182 - val_loss: 0.5339
# Epoch 130/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8683 - loss: 0.4886 - val_accuracy: 0.8182 - val_loss: 0.5337
# Epoch 131/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8570 - loss: 0.4747 - val_accuracy: 0.8264 - val_loss: 0.5296
# Epoch 132/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8396 - loss: 0.5046 - val_accuracy: 0.8430 - val_loss: 0.5270
# Epoch 133/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8679 - loss: 0.4963 - val_accuracy: 0.8512 - val_loss: 0.5279
# Epoch 134/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8829 - loss: 0.4200 - val_accuracy: 0.8678 - val_loss: 0.5259
# Epoch 135/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9171 - loss: 0.4204 - val_accuracy: 0.8678 - val_loss: 0.5241
# Epoch 136/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9016 - loss: 0.4029 - val_accuracy: 0.8512 - val_loss: 0.5212
# Epoch 137/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8397 - loss: 0.5432 - val_accuracy: 0.8430 - val_loss: 0.5180
# Epoch 138/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8375 - loss: 0.5010 - val_accuracy: 0.8512 - val_loss: 0.5171
# Epoch 139/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9274 - loss: 0.3920 - val_accuracy: 0.8512 - val_loss: 0.5161
# Epoch 140/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8590 - loss: 0.4532 - val_accuracy: 0.8595 - val_loss: 0.5111
# Epoch 141/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9338 - loss: 0.3722 - val_accuracy: 0.8595 - val_loss: 0.5068
# Epoch 142/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9163 - loss: 0.3748 - val_accuracy: 0.8595 - val_loss: 0.5032
# Epoch 143/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8978 - loss: 0.4142 - val_accuracy: 0.8595 - val_loss: 0.5038
# Epoch 144/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8648 - loss: 0.4989 - val_accuracy: 0.8595 - val_loss: 0.5008
# Epoch 145/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8950 - loss: 0.4136 - val_accuracy: 0.8512 - val_loss: 0.4953
# Epoch 146/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8857 - loss: 0.3821 - val_accuracy: 0.8512 - val_loss: 0.4905
# Epoch 147/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9016 - loss: 0.4258 - val_accuracy: 0.8512 - val_loss: 0.4840
# Epoch 148/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8858 - loss: 0.4005 - val_accuracy: 0.8430 - val_loss: 0.4814
# Epoch 149/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9076 - loss: 0.4050 - val_accuracy: 0.8264 - val_loss: 0.4837
# Epoch 150/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8786 - loss: 0.4368 - val_accuracy: 0.8347 - val_loss: 0.4829
# Epoch 151/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9189 - loss: 0.3700 - val_accuracy: 0.8430 - val_loss: 0.4762
# Epoch 152/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8931 - loss: 0.3707 - val_accuracy: 0.8678 - val_loss: 0.4742
# Epoch 153/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8664 - loss: 0.4258 - val_accuracy: 0.8595 - val_loss: 0.4717
# Epoch 154/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9011 - loss: 0.3594 - val_accuracy: 0.8347 - val_loss: 0.4718
# Epoch 155/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9182 - loss: 0.3623 - val_accuracy: 0.8430 - val_loss: 0.4720
# Epoch 156/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8954 - loss: 0.4041 - val_accuracy: 0.8595 - val_loss: 0.4651
# Epoch 157/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9261 - loss: 0.3470 - val_accuracy: 0.8595 - val_loss: 0.4608
# Epoch 158/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.3719 - val_accuracy: 0.8595 - val_loss: 0.4624
# Epoch 159/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8999 - loss: 0.3901 - val_accuracy: 0.8595 - val_loss: 0.4597
# Epoch 160/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9355 - loss: 0.3450 - val_accuracy: 0.8595 - val_loss: 0.4605
# Epoch 161/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9164 - loss: 0.3570 - val_accuracy: 0.8678 - val_loss: 0.4582
# Epoch 162/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9139 - loss: 0.3569 - val_accuracy: 0.8760 - val_loss: 0.4569
# Epoch 163/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.4231 - val_accuracy: 0.8678 - val_loss: 0.4567
# Epoch 164/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8686 - loss: 0.4629 - val_accuracy: 0.8760 - val_loss: 0.4540
# Epoch 165/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9075 - loss: 0.3624 - val_accuracy: 0.8678 - val_loss: 0.4543
# Epoch 166/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8731 - loss: 0.4182 - val_accuracy: 0.8678 - val_loss: 0.4544
# Epoch 167/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9275 - loss: 0.3178 - val_accuracy: 0.8595 - val_loss: 0.4551
# Epoch 168/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9052 - loss: 0.3564 - val_accuracy: 0.8595 - val_loss: 0.4476
# Epoch 169/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9476 - loss: 0.2866 - val_accuracy: 0.8595 - val_loss: 0.4439
# Epoch 170/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.3108 - val_accuracy: 0.8595 - val_loss: 0.4460
# Epoch 171/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9228 - loss: 0.2935 - val_accuracy: 0.8595 - val_loss: 0.4481
# Epoch 172/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8973 - loss: 0.3647 - val_accuracy: 0.8595 - val_loss: 0.4460
# Epoch 173/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9062 - loss: 0.3392 - val_accuracy: 0.8678 - val_loss: 0.4419
# Epoch 174/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9103 - loss: 0.3408 - val_accuracy: 0.8595 - val_loss: 0.4442
# Epoch 175/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9245 - loss: 0.3321 - val_accuracy: 0.8595 - val_loss: 0.4440
# Epoch 176/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9368 - loss: 0.3007 - val_accuracy: 0.8595 - val_loss: 0.4426
# Epoch 177/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9276 - loss: 0.3299 - val_accuracy: 0.8595 - val_loss: 0.4436
# Epoch 178/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9166 - loss: 0.3450 - val_accuracy: 0.8595 - val_loss: 0.4428
# Epoch 179/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8971 - loss: 0.3964 - val_accuracy: 0.8595 - val_loss: 0.4398
# Epoch 180/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9112 - loss: 0.3115 - val_accuracy: 0.8512 - val_loss: 0.4400
# Epoch 181/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8969 - loss: 0.3620 - val_accuracy: 0.8512 - val_loss: 0.4370
# Epoch 182/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9000 - loss: 0.3354 - val_accuracy: 0.8430 - val_loss: 0.4384
# Epoch 183/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9071 - loss: 0.3290 - val_accuracy: 0.8512 - val_loss: 0.4369
# Epoch 184/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9405 - loss: 0.2838 - val_accuracy: 0.8595 - val_loss: 0.4324
# Epoch 185/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8823 - loss: 0.3730 - val_accuracy: 0.8678 - val_loss: 0.4295
# Epoch 186/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9380 - loss: 0.3004 - val_accuracy: 0.8678 - val_loss: 0.4239
# Epoch 187/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9268 - loss: 0.3065 - val_accuracy: 0.8678 - val_loss: 0.4233
# Epoch 188/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8751 - loss: 0.4403 - val_accuracy: 0.8678 - val_loss: 0.4273
# Epoch 189/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9018 - loss: 0.3431 - val_accuracy: 0.8678 - val_loss: 0.4302
# Epoch 190/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8806 - loss: 0.3760 - val_accuracy: 0.8595 - val_loss: 0.4300
# Epoch 191/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9320 - loss: 0.2979 - val_accuracy: 0.8678 - val_loss: 0.4296
# Epoch 192/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.2758 - val_accuracy: 0.8678 - val_loss: 0.4223
# Epoch 193/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9593 - loss: 0.2644 - val_accuracy: 0.8678 - val_loss: 0.4214
# Epoch 194/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9171 - loss: 0.2847 - val_accuracy: 0.8678 - val_loss: 0.4225
# Epoch 195/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9203 - loss: 0.2822 - val_accuracy: 0.8678 - val_loss: 0.4212
# Epoch 196/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9405 - loss: 0.3026 - val_accuracy: 0.8678 - val_loss: 0.4183
# Epoch 197/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9082 - loss: 0.3487 - val_accuracy: 0.8678 - val_loss: 0.4200
# Epoch 198/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9454 - loss: 0.2632 - val_accuracy: 0.8678 - val_loss: 0.4186
# Epoch 199/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9384 - loss: 0.2657 - val_accuracy: 0.8678 - val_loss: 0.4144
# Epoch 200/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9222 - loss: 0.2963 - val_accuracy: 0.8595 - val_loss: 0.4091
# Restoring model weights from the end of the best epoch: 200.
# Validation Accuracy for Fold 3: 85.95%
# Average Validation Accuracy over 3 folds: 89.83%

# %%
import matplotlib.pyplot as plt

# Plot the training loss curve w.r.t epoch
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.title('Training Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot the training and validation accuracy w.r.t epoch
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
